# %%
import pandas as pd
import numpy as np
file=pd.read_csv("C:/Users/Sinegalatha/Desktop/Imarticus Learning/assessment exam/MonthWiseMarketArrivals_Clean.csv")
df=pd.DataFrame(file)
df
# Out:
#            market     month  year  quantity  priceMin  priceMax  priceMod  \
# 0      ABOHAR(PB)   January  2005      2350       404       493       446
# 1      ABOHAR(PB)   January  2006       900       487       638       563
# 2      ABOHAR(PB)   January  2010       790      1283      1592      1460
# 3      ABOHAR(PB)   January  2011       245      3067      3750      3433
# 4      ABOHAR(PB)   January  2012      1035       523       686       605
# ...           ...       ...   ...       ...       ...       ...       ...
# 10222   YEOLA(MS)  December  2011    131326       282       612       526
# 10223   YEOLA(MS)  December  2012    207066       485      1327      1136
# 10224   YEOLA(MS)  December  2013    215883       472      1427      1177
# 10225   YEOLA(MS)  December  2014    201077       446      1654      1456
# 10226   YEOLA(MS)  December  2015    223315       609      1446      1126
#
#       state    city           date
# 0        PB  ABOHAR   January-2005
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10227 entries, 0 to 10226
# Data columns (total 10 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   market    10227 non-null  object
#  1   month     10227 non-null  object
#  2   year      10227 non-null  int64
#  3   quantity  10227 non-null  int64
#  4   priceMin  10227 non-null  int64
#  5   priceMax  10227 non-null  int64
#  6   priceMod  10227 non-null  int64
#  7   state     10227 non-null  object
#  8   city      10227 non-null  object
#  9   date      10227 non-null  object
# dtypes: int64(5), object(5)
# memory usage: 799.1+ KB

# %%
df.head(10)
# Out:
#        market     month  year  quantity  priceMin  priceMax  priceMod state  \
# 0  ABOHAR(PB)   January  2005      2350       404       493       446    PB
# 1  ABOHAR(PB)   January  2006       900       487       638       563    PB
# 2  ABOHAR(PB)   January  2010       790      1283      1592      1460    PB
# 3  ABOHAR(PB)   January  2011       245      3067      3750      3433    PB
# 4  ABOHAR(PB)   January  2012      1035       523       686       605    PB
# 5  ABOHAR(PB)   January  2013       675      1327      1900      1605    PB
# 6  ABOHAR(PB)   January  2014       440      1025      1481      1256    PB
# 7  ABOHAR(PB)   January  2015      1305      1309      1858      1613    PB
# 8  ABOHAR(PB)  February  2005      1400       286       365       324    PB
# 9  ABOHAR(PB)  February  2006      1800       343       411       380    PB
#
#      city           date
# 0  ABOHAR   January-2005
# 1  ABOHAR   January-2006
# 2  ABOHAR   January-2010
# 3  ABOHAR   January-2011
# ...

# %%
df.shape
# Out:
# (10227, 10)

# %%
df.describe()
# Out:
#                year      quantity      priceMin      priceMax      priceMod
# count  10227.000000  1.022700e+04  10227.000000  10227.000000  10227.000000
# mean    2009.022294  7.660488e+04    646.944363   1212.760731    984.284345
# std        4.372841  1.244087e+05    673.121850    979.658874    818.471498
# min     1996.000000  2.000000e+01     16.000000    145.000000     80.000000
# 25%     2006.000000  8.898000e+03    209.000000    557.000000    448.000000
# 50%     2009.000000  2.746000e+04    440.000000    923.000000    747.000000
# 75%     2013.000000  8.835650e+04    828.000000   1527.000000   1248.000000
# max     2016.000000  1.639032e+06   6000.000000   8192.000000   6400.000000

# %%
df['date']=pd.to_datetime(df['date'])

# %%
df
# Out:
#            market     month  year  quantity  priceMin  priceMax  priceMod  \
# 0      ABOHAR(PB)   January  2005      2350       404       493       446
# 1      ABOHAR(PB)   January  2006       900       487       638       563
# 2      ABOHAR(PB)   January  2010       790      1283      1592      1460
# 3      ABOHAR(PB)   January  2011       245      3067      3750      3433
# 4      ABOHAR(PB)   January  2012      1035       523       686       605
# ...           ...       ...   ...       ...       ...       ...       ...
# 10222   YEOLA(MS)  December  2011    131326       282       612       526
# 10223   YEOLA(MS)  December  2012    207066       485      1327      1136
# 10224   YEOLA(MS)  December  2013    215883       472      1427      1177
# 10225   YEOLA(MS)  December  2014    201077       446      1654      1456
# 10226   YEOLA(MS)  December  2015    223315       609      1446      1126
#
#       state    city       date
# 0        PB  ABOHAR 2005-01-01
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10227 entries, 0 to 10226
# Data columns (total 10 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   market    10227 non-null  object
#  1   month     10227 non-null  object
#  2   year      10227 non-null  int64
#  3   quantity  10227 non-null  int64
#  4   priceMin  10227 non-null  int64
#  5   priceMax  10227 non-null  int64
#  6   priceMod  10227 non-null  int64
#  7   state     10227 non-null  object
#  8   city      10227 non-null  object
#  9   date      10227 non-null  datetime64[ns]
# dtypes: datetime64[ns](1), int64(5), object(4)
# memory usage: 799.1+ KB

# %%
df.isna().sum()
# Out:
# market      0
# month       0
# year        0
# quantity    0
# priceMin    0
# priceMax    0
# priceMod    0
# state       0
# city        0
# date        0
# dtype: int64

# %%
df[df.duplicated()]
# Out:
# Empty DataFrame
# Columns: [market, month, year, quantity, priceMin, priceMax, priceMod, state, city, date]
# Index: []

# %%
df.set_index(['date'],inplace=True)

# %%
df.drop(['market','month','year','quantity','priceMin','priceMax','state','city'],axis=True,inplace=True)
df=df.sort_values('date')
df.tail(300)
# Out:
#             priceMod
# date
# 2015-11-01      2300
# 2015-11-01      1547
# 2015-11-01      1482
# 2015-11-01      1438
# 2015-11-01      2433
# ...              ...
# 2016-02-01      1077
# 2016-02-01       575
# 2016-02-01       730
# 2016-02-01       806
# 2016-02-01      1309
#
# [300 rows x 1 columns]

# %%
df
# Out:
#             priceMod
# date
# 1996-01-01       226
# 1996-02-01       186
# 1996-03-01       243
# 1996-04-01       254
# 1996-05-01       269
# ...              ...
# 2016-02-01      1077
# 2016-02-01       575
# 2016-02-01       730
# 2016-02-01       806
# 2016-02-01      1309
#
# [10227 rows x 1 columns]

# %%
import matplotlib.pyplot as mtp
from matplotlib.pylab import rcParams
rcParams['figure.figsize']=20,10
mtp.plot(df)
mtp.xticks(rotation=30)
# Out:
# (array([727198., 728659., 730120., 731581., 733042., 734503., 735964.,
#         737425.]),
#  <a list of 8 Text major ticklabel objects>)

# %% [markdown]
# # the series in stationary

# %%
from statsmodels.tsa.seasonal import seasonal_decompose
mul_result=seasonal_decompose(df.iloc[0:1000,:],model='multiplicative',period=1)
add_result=seasonal_decompose(df.iloc[0:1000,:],model='addictive',period=1)
mul_result

# %%
from statsmodels.tsa.stattools import kpss
kpss_test=kpss(df.iloc[0:1000,:])
print('Test Statistics',kpss_test[0])
print('P value',kpss_test[1])
# Out:
# Test Statistics 0.48614760175778055
# P value 0.04478657618068006
# C:\Users\Sinegalatha\anaconda3\lib\site-packages\statsmodels\tsa\stattools.py:1661: FutureWarning: The behavior of using lags=None will change in the next release. Currently lags=None is the same as lags='legacy', and so a sample-size lag length is used. After the next release, the default will change to be the same as lags='auto' which uses an automatic lag length selection method. To silence this warning, either use 'auto' or 'legacy'
#   warn(msg, FutureWarning)

# %%
rcParams['figure.figsize']=15,3
mtp.plot(df,label='original')
mtp.legend(loc='best')
mtp.show()
mtp.plot(add_result.trend,label='trend')
mtp.legend(loc='best')
mtp.show()
mtp.plot(add_result.seasonal,label='seasonal')
mtp.legend(loc='best')
mtp.show()
mtp.plot(add_result.resid,label='residual')
mtp.legend(loc='best')
mtp.show()

# %%
from statsmodels.tsa.arima.model import ARIMA
ari=ARIMA(data)
ari=ari.fit()
# Out:
# C:\Users\Sinegalatha\anaconda3\lib\site-packages\statsmodels\tsa\base\tsa_model.py:216: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   warnings.warn('A date index has been provided, but it has no'
# C:\Users\Sinegalatha\anaconda3\lib\site-packages\statsmodels\tsa\base\tsa_model.py:216: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   warnings.warn('A date index has been provided, but it has no'
# C:\Users\Sinegalatha\anaconda3\lib\site-packages\statsmodels\tsa\base\tsa_model.py:216: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   warnings.warn('A date index has been provided, but it has no'

# %%
ari.summary().tables[1]
# Out:
# <class 'statsmodels.iolib.table.SimpleTable'>

# %%
pred = ari.get_prediction(start=pd.to_datetime('2015-11-01'), dynamic=False)

# %%
pred_ci = pred.conf_int()
pred_ci
# Out:
#             lower priceMod  upper priceMod
# date
# 2015-11-01     -866.933991      867.145681
# 2015-11-01     -866.933991      867.145681
# 2015-11-01     -866.933991      867.145681
# 2015-11-01     -866.933991      867.145681
# 2015-11-01     -866.933991      867.145681
# ...                    ...             ...
# 2016-02-01     -866.933991      867.145681
# 2016-02-01     -866.933991      867.145681
# 2016-02-01     -866.933991      867.145681
# 2016-02-01     -866.933991      867.145681
# 2016-02-01     -866.933991      867.145681
#
# [346 rows x 2 columns]

# %%
test=data[-346::]
Actual = test
Predicted= pred_ci['upper priceMod']

# %%
import math
from sklearn.metrics import mean_squared_error
print(math.sqrt(mean_squared_error(Actual,Predicted)))
# Out:
# 1089.8962983188737
